# %%
import json
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
with open("./logs/Pong-v0.json", 'r') as f:
    print f
    pong_Base_D = json.load(f)
# Out:
# <open file './logs/Pong-v0.json', mode 'r' at 0x7f9396d2c780>

# %%
print pong_Base_D.keys()
# Out:
# [u'avg_q', u'avg_reward', u'total_reward', u'total_q']

# %%
with open("./logs/Breakout-v0.json", 'r') as f:
    print f
    BfP_D = json.load(f)
# Out:
# <open file './logs/Breakout-v0.json', mode 'r' at 0x7f939920f8a0>

# %%
plt.plot(D["avg_q"])
plt.plot(BfP_D['avg_q'])
plt.title("AVG - Q")

# %%
print len(BfP_D['avg_reward'])
# Out:
# 82

# %%
plt.plot(pong_Base_D['avg_reward'][:80])
plt.plot(BfP_D['avg_reward'])
plt.title('Episode Reward')
