# %%
import json
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
with open("./logs/Pong-v0.json", 'r') as f:
    print f
    D = json.load(f)
# Out:
# <open file './logs/Pong-v0.json', mode 'r' at 0x7efdd45858a0>

# %%
print D.keys()
# Out:
# [u'avg_q', u'total_reward', u'avg_reward', u'total_q']

# %%
plt.plot(D["avg_q"])
plt.title("AVG - Q")

# %%
plt.plot(D['avg_reward'])
plt.title('Episode Reward')
